# %% [markdown]
# # Live Input and Output
# ## Connecting to a SpiNNaker board
# <img src="SpiNNakerPorts.png" />
#
# Communication with the outside world from a SpiNNaker simulation can be done using one of the following:
# - SpiNNaker Link connection.  This is a direct connection in to the router of one of the chips and as such can operate at the full bandwidth of the router.  There are 2 of these connections on a 4-node board and 1 on each 48-node board.  All of these can be used in a multi-board configuration, but the FPGA connection on the same link *must be disabled* in this case, as this can otherwise overload and physically break the link.
# - SpiNN-Link connection.  This is a connection to the SATA-connectors on the board, which then interfaces with the FPGAs on the board.  This connection can operate at the speed of the interface between the boards, and has access to multiple chips on the board-side of the connection.  There are 9 such connectors on each 48-node board, though 6 of those are used for the connections between boards in multi-board machines.  This requires the FPGA that the link is connected to to be configured to forward traffic to and from the chips on the board.  This is *not* performed by the software so additional development is required here.
# - Ethernet connection.  This connects via the monitor core of the first chip on each board.  As such it is the slowest of the connections, but as it works hardware that most PCs have, it is the easiest to use.

# %% [markdown]
# ## Communicating over Ethernet
# The SpiNNaker software extends PyNN by allowing live input into and live output out of a neural network running on the platform.  The SpiNNaker software provides a number of different ways for a PyNN simulation to communicate.  These are described below.  In all cases the external agent can discover information about a running simulation through a database that can be written before the simulation starts executing on the machine; this includes the placement of the parts of a Population on the machine, and the multicast keys which are being used to send spikes and/or commands, allowing the agent to decode information being received, or encode information being sent.
#
# External agents can register to receive notifications from the software when the database has been written, when the simulation starts (or resumes after a pause), and when the simulation ends (or is paused).  The software will send these notifications as UDP messages.  After the database message, the agent is expected to reply to indicate that it is ready for the simulation to start; the software will pause until this has been received to ensure that the agent is ready.
#
# A number of "Connection" implementations are provided to help in the construction of the external agent.  These can be requested to call functions when certain events occur, such as when the simulation is starting or finishing, or when a message has been received from the simulation.  The port on which these connections listen for the notification messages from the simulation software can be registered during the calls made as the simulation is set up.  These details will also be discussed below.
#
# The normal order of operation to set up an external communication is as follows:
# 1. Set up the "external agent" connections so that they are ready to listen for notification messages from the software.  These may have to be executed in a separate thread or process, but the connection implementations take care of this.
# 1. During the PyNN simulation specification, ensure that the connection details are registered with the software.
# 1. Run the simulation.

# %% [markdown]
# ### Live Spike Input - SpikeInjector
#
# <img src="SpikeInjector.png">
#
# Spikes can be sent into a PyNN simulation by using a ```SpikeInjector``` as the model of a Population.  This model expects to receive SpiNNaker Datagram Protocol (SDP) messages containing spikes.  A ```SpynnakerLiveSpikesConnection``` can be used by an external agent to send the ```SpikeInjector``` these messages without having to understand the details.  Note that a single connection can be used to send spikes to multiple sources.
#
# The following is an example of live spike transmission:

# %%
# Import the simulator
import spynnaker.pyNN as sim

# Other imports used in this example
from time import sleep


# Set up a function that will start sending spikes when the simulation starts.
# This is automatically run in a separate thread from the rest of the simulation.
# This must accept two arguments: 
#    The label of the Population that the callback is registered against, 
#    and the connection the callback is registered against.
def send_spikes(label, connection):
    # Sleep to make sure everything is fully ready
    sleep(0.01)
    
    # Send a spike to neuron 0
    connection.send_spike(label, 0)
    
    # Send spikes to neurons 1-4 after 0.1ms
    sleep(0.1)
    connection.send_spikes(label, range(1, 5))


# Keep track of the label of the injector as this needs to match up in several places
injector_label = "injector"

# Create the connection, noting that the label will be a "sender".
# Note the use of local_port=None allows the automatic assignment of a port.
connection = sim.external_devices.SpynnakerLiveSpikesConnection(
    local_port=None, send_labels=[injector_label])

# Add a callback to be called at the start of the simulation
connection.add_start_resume_callback(injector_label, send_spikes)

# Set up the simulation itself
sim.setup(1.0)

# Set up the injector population with 5 neurons, 
# simultaneously registering the connection as a listener
injector = sim.Population(
    5, sim.external_devices.SpikeInjector(
        database_notify_port_num=connection.local_port),
    # Critical: Make sure the label is used!
    label=injector_label)

# Set up a Population to receive spikes and record
pop = sim.Population(5, sim.IF_curr_exp(), label="pop")
pop.record("spikes")

# Connect the injector to the population
sim.Projection(injector, pop, sim.OneToOneConnector(), sim.StaticSynapse(weight=5))

# Run the simulation and get the spikes out
sim.run(1000)
spikes = pop.get_data("spikes").segments[0].spiketrains

# End the simulation and display the spikes
sim.end()
print(spikes)
# Out:
# 2024-01-16 17:28:54 INFO: Read configs files: /home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg, /home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2024-01-16 17:28:54 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries
# 2024-01-16 17:28:55 WARNING: /home/bbpnrsoa/reports/reports has 75 old reports that have not been closed
# 2024-01-16 17:28:55 INFO: Setting hardware timestep as 1000 microseconds based on simulation time step of 1000 and timescale factor of 1.0
# 2024-01-16 17:28:55 INFO: Starting execution process
# 2024-01-16 17:28:55 INFO: Simulating for 1000 1.0 ms timesteps using a hardware timestep of 1000 us
# ['/home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg', '/home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2024-01-16 17:28:55 INFO: SpYNNakerNeuronGraphNetworkSpecificationReport skipped as cfg Reports:write_network_graph is False
# 2024-01-16 17:28:55 INFO: Network Specification report took 0:00:00.000762
# 2024-01-16 17:28:55 INFO: Splitter reset took 0:00:00.000036
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:28:55 INFO: Spynnaker splitter selector took 0:00:00.028546
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:28:55 INFO: DelaySupportAdder took 0:00:00.023509
# Partitioning Graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:28:55 INFO: Splitter partitioner took 0:00:00.016838
# 2024-01-16 17:28:55 INFO: 0.02 Boards Required for 1 chips
# 2024-01-16 17:28:55 INFO: Requesting job with 1 boards
# Created spalloc job 379108
# 2024-01-16 17:28:55 INFO: Created spalloc job 379108
# Job has been queued by the spalloc server.
# 2024-01-16 17:28:55 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2024-01-16 17:28:55 INFO: Waiting for board power commands to complete.
# 2024-01-16 17:29:04 INFO: SpallocAllocator took 0:00:09.316576
# 2024-01-16 17:29:04 INFO: Creating transceiver for 10.11.219.177
# 2024-01-16 17:29:04 INFO: Working out if machine is booted
# 2024-01-16 17:29:08 INFO: Attempting to boot machine
# 2024-01-16 17:29:16 INFO: Found board with version [Version: SC&MP 4.0.0 at SpiNNaker:0:0:0 (built Fri Nov 17 10:35:48 2023)]
# 2024-01-16 17:29:16 INFO: Machine communication successful
# 2024-01-16 17:29:16 INFO: 10.11.219.177
# Reading details from 47 chips
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:16 INFO: Detected Machine on 10.11.219.177 with 47 Chips, 836 cores and 114.0 links. Chips have sdram of 123469792 bytes, router table of size 1023, between 17 and 18 cores and between 3 and 6 links.
# 2024-01-16 17:29:16 INFO: Machine generator took 0:00:12.396480
# 2024-01-16 17:29:17 INFO: Json machine skipped as cfg Reports:write_json_machine is False
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Board chip report took 0:00:00.016259
# Adding commands
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Command Sender Adder took 0:00:00.021258
# 2024-01-16 17:29:17 INFO: Split Live Gather Vertices took 0:00:00.000038
# 2024-01-16 17:29:17 INFO: Insert chip power monitors skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:29:17 INFO: Insert extra monitor vertices took 0:00:00.000056
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Partitioner report took 0:00:00.010471
# Placing Vertices
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Application Placer took 0:00:00.012274
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Placements with application graph report took 0:00:00.065221
# 2024-01-16 17:29:17 INFO: Json placements skipped as cfg Reports:write_json_placements is False
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: System multicast routing generator took 0:00:00.014929
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-01-16 17:29:17 INFO: Fixed route router took 0:00:00.021898
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Application Router took 0:00:00.013379
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Basic tag allocator took 0:00:00.053163
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Tag allocator report took 0:00:00.017747
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Zoned routing info allocator took 0:00:00.107959
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Router info report took 0:00:00.003701
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Merged routing table generator took 0:00:00.019884
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Uncompressed routing table report took 0:00:00.010740
# 2024-01-16 17:29:17 INFO: Router report skipped as cfg Reports:write_router_reports is False
# 2024-01-16 17:29:17 INFO: Router summary report skipped as cfg Reports:write_router_summary_report is False
# 2024-01-16 17:29:17 INFO: Json routing tables skipped as cfg Reports:write_json_routing_tables is False
# 2024-01-16 17:29:17 INFO: Locate executable start type took 0:00:00.000502
# 2024-01-16 17:29:17 INFO: Buffer manager creator took 0:00:00.002052
# 2024-01-16 17:29:17 INFO: Write Neo Metadata took 0:00:00.006074
# 2024-01-16 17:29:17 INFO: Record vertex labels to database took 0:00:00.003074
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Routing setup took 0:00:00.012527
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: Graph binary gatherer took 0:00:00.126553
# 2024-01-16 17:29:17 INFO: Pair on chip router compression skipped as Tables already small enough
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:17 INFO: SDRAM outgoing partition allocator took 0:00:00.003656
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:18 INFO: Graph data specification writer took 0:00:00.283087
# 2024-01-16 17:29:18 INFO: Control Sync took 0:00:00.000668
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:18 INFO: Load fixed routes took 0:00:00.071635
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:22 INFO: Load system data specification took 0:00:04.080500
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:22 INFO: Load executable system Images took 0:00:00.361357
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:22 INFO: Tags Loader took 0:00:00.036169
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:26 INFO: Load Application data specification took 0:00:03.696755
# Preparing to Expand Neuron Data
# |0%                          50%                         100%|
#  ============================================================
# Expanding Neuron Data
# |0%                          50%                         100%|
#  ============================================================
#
# Getting initial values
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:27 INFO: Neuron expander took 0:00:00.773901
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# Expanding Synapses
# |0%                          50%                         100%|
#  ============================================================
#
# Reading generated connections
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-01-16 17:29:27 INFO: Synapse expander took 0:00:00.856526
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Finish connection holders took 0:00:00.012823
# Loading routing data onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Routing table loader took 0:00:00.014105
# 2024-01-16 17:29:28 INFO: Bitfield compressor report skipped as cfg Reports:write_bit_field_compressor_report is False
# 2024-01-16 17:29:28 INFO: Tags from machine report took 0:00:00.003445
# 2024-01-16 17:29:28 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# 2024-01-16 17:29:28 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Compressor report took 0:00:00.084045
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Fixed route report took 0:00:00.074372
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Load executable app images took 0:00:00.587178
# 2024-01-16 17:29:28 INFO: Running for 1 steps for a total of 1000.0ms
# 2024-01-16 17:29:28 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Sdram usage per chip report took 0:00:00.126879
# 2024-01-16 17:29:28 INFO: Drift report skipped as cfg Reports:write_drift_report_start is False
# 2024-01-16 17:29:28 INFO: Creating live event connection database in /home/bbpnrsoa/reports/reports/2024-01-16-17-28-54-912532/run_1/input_output_database.sqlite3
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:28 INFO: Create database interface took 0:00:00.051149
# 2024-01-16 17:29:29 INFO: ** Notifying external sources that the database is ready for reading **
# 2024-01-16 17:29:29 INFO: 0.0.0.0:34633 Reading database
# 2024-01-16 17:29:29 INFO: database is at /home/bbpnrsoa/reports/reports/2024-01-16-17-28-54-912532/run_1/input_output_database.sqlite3
# 2024-01-16 17:29:29 INFO: Notifying the toolchain that the database has been read
# 2024-01-16 17:29:29 INFO: Waiting for message to indicate that the simulation has started or resumed
# 2024-01-16 17:29:29 INFO: ** Confirmation from 127.0.0.1:34633 received, continuing **
# 2024-01-16 17:29:29 INFO: Create notification protocol took 0:00:00.006709
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:29 INFO: Runtime Update took 0:00:00.067092
# 2024-01-16 17:29:29 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:29 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:29:29 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2024-01-16 17:29:29 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:29:29 INFO: Waiting for message to indicate that the simulation has stopped or paused
# 2024-01-16 17:29:29 INFO: Application started; waiting 1.1s for it to stop
# 2024-01-16 17:29:30 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2024-01-16 17:29:30 INFO: Application runner took 0:00:01.245263
# 2024-01-16 17:29:30 INFO: Extract IO buff skipped as cfg Reports:extract_iobuf is False
# 2024-01-16 17:29:30 INFO: Starting buffer extraction using Java
# 2024-01-16 17:29:34 INFO: Buffer extractor took 0:00:03.795123
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:34 INFO: Clear IO buffer took 0:00:00.054588
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:34 INFO: Graph provenance gatherer took 0:00:00.014761
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:34 INFO: Placements provenance gatherer took 0:00:00.353806
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:34 INFO: Router provenance gatherer took 0:00:00.290563
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:34 INFO: Profile data gatherer took 0:00:00.042240
# 2024-01-16 17:29:34 INFO: Energy report skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:29:34 INFO: Redundant packet count report took 0:00:00.007439
# 2024-01-16 17:29:34 INFO: Drift report skipped as cfg Reports:write_drift_report_end is False
# 2024-01-16 17:29:35 INFO: Control Sync took 0:00:00.000799
# [<SpikeTrain(array([21.]) * ms, [0.0 ms, 1000.0 ms])>, <SpikeTrain(array([122.]) * ms, [0.0 ms, 1000.0 ms])>, <SpikeTrain(array([122.]) * ms, [0.0 ms, 1000.0 ms])>, <SpikeTrain(array([122.]) * ms, [0.0 ms, 1000.0 ms])>, <SpikeTrain(array([122.]) * ms, [0.0 ms, 1000.0 ms])>]

# %% [markdown]
# ### Live Spike Output - activate_live_output_for
#
# <img src="SpikeOutput.png">
#
# Spikes can be received from a PyNN simulation by calling a special function ```activate_live_output_for```, passing in the population from which the spikes are to be received, as well as other parameters to specify the properties of the communication. This will cause the simulation to send SpiNNaker Datagram Protocol (SDP) messages containing spikes from the machine during the simulation. Again, a ```SpynnakerLiveSpikesConnection``` can be used by an external agent to receive these messages without having to understand the details.  Note that a single connection can be used to receive spikes from multiple sources, and can also send spikes as described in the previous section.
#
# The following is an example of live spike output:

# %%
# Import the simulator
import spynnaker.pyNN as sim

# Set up a function that will receive spikes.
# This is automatically run in a separate thread from the rest of the simulation.
# This must accept three arguments: 
#    The label of the Population that the callback is registered against, 
#    the time at which a spikes are received, in units of simulation time step,
#    and the neuron ids that spiked at this time.
def receive_spikes(label, time, neuron_ids):
    print("Received spikes {} from {} at time {}".format(neuron_ids, label, time))


# Keep track of the label of the Population
pop_label = "pop"

# Create the connection, noting that the label will be a "receiver".
# Note the use of local_port=None allows the automatic assignment of a port.
connection = sim.external_devices.SpynnakerLiveSpikesConnection(
    local_port=None, receive_labels=[pop_label])

# Add a callback to be called when spikes are received
connection.add_receive_callback(pop_label, receive_spikes)

# Set up the simulation itself
sim.setup(1.0)

# Set up a population which will spike
pop = sim.Population(
    5, sim.SpikeSourcePoisson(rate=10),
    # Critical: Make sure the label is used!
    label=pop_label)

# Activate the live output, 
# simultaneously registering the connection as a listener
sim.external_devices.activate_live_output_for(
    pop, database_notify_port_num=connection.local_port)

# Run the simulation
sim.run(1000)

# End the simulation
sim.end()
# Out:
# 2024-01-16 17:29:35 INFO: 0.0.0.0:43906 Waiting for message to indicate that the database is ready
# 2024-01-16 17:29:35 INFO: Receive callback <function receive_spikes at 0x7f790d6dbee0> registered to label pop
# 2024-01-16 17:29:35 INFO: Read configs files: /home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg, /home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2024-01-16 17:29:35 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries : /home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries
# 2024-01-16 17:29:35 WARNING: /home/bbpnrsoa/reports/reports has 76 old reports that have not been closed
# 2024-01-16 17:29:35 INFO: Setting hardware timestep as 1000 microseconds based on simulation time step of 1000 and timescale factor of 1.0
# 2024-01-16 17:29:35 INFO: Starting execution process
# 2024-01-16 17:29:35 INFO: Simulating for 1000 1.0 ms timesteps using a hardware timestep of 1000 us
# ['/home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg', '/home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2024-01-16 17:29:35 INFO: SpYNNakerNeuronGraphNetworkSpecificationReport skipped as cfg Reports:write_network_graph is False
# 2024-01-16 17:29:35 INFO: Network Specification report took 0:00:00.000818
# 2024-01-16 17:29:35 INFO: Splitter reset took 0:00:00.000069
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:35 INFO: Spynnaker splitter selector took 0:00:00.016140
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:35 INFO: DelaySupportAdder took 0:00:00.006049
# Partitioning Graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:35 INFO: Splitter partitioner took 0:00:00.065995
# 2024-01-16 17:29:35 INFO: 0.02 Boards Required for 1 chips
# 2024-01-16 17:29:35 INFO: Requesting job with 1 boards
# Created spalloc job 379109
# 2024-01-16 17:29:35 INFO: Created spalloc job 379109
# Job has been queued by the spalloc server.
# 2024-01-16 17:29:35 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2024-01-16 17:29:35 INFO: Waiting for board power commands to complete.
# 2024-01-16 17:29:44 INFO: SpallocAllocator took 0:00:09.131931
# 2024-01-16 17:29:44 INFO: Creating transceiver for 10.11.200.177
# 2024-01-16 17:29:44 INFO: Working out if machine is booted
# 2024-01-16 17:29:48 INFO: Attempting to boot machine
# 2024-01-16 17:29:56 INFO: Found board with version [Version: SC&MP 4.0.0 at SpiNNaker:0:0:0 (built Fri Nov 17 10:35:48 2023)]
# 2024-01-16 17:29:56 INFO: Machine communication successful
# 2024-01-16 17:29:56 INFO: 10.11.200.177
# Reading details from 48 chips
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:56 INFO: Detected Machine on 10.11.200.177 with 48 Chips, 856 cores and 120.0 links. Chips have sdram of 123469792 bytes, router table of size 1023, between 17 and 18 cores and between 3 and 6 links.
# 2024-01-16 17:29:56 INFO: Machine generator took 0:00:12.278347
# 2024-01-16 17:29:56 INFO: Json machine skipped as cfg Reports:write_json_machine is False
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:56 INFO: Board chip report took 0:00:00.021726
# Adding commands
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:56 INFO: Command Sender Adder took 0:00:00.020672
# 2024-01-16 17:29:56 INFO: Split Live Gather Vertices took 0:00:00.000278
# 2024-01-16 17:29:56 INFO: Insert chip power monitors skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:29:56 INFO: Insert extra monitor vertices took 0:00:00.000065
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Partitioner report took 0:00:00.025088
# Placing Vertices
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Application Placer took 0:00:00.022950
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Placements with application graph report took 0:00:00.087620
# 2024-01-16 17:29:57 INFO: Json placements skipped as cfg Reports:write_json_placements is False
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: System multicast routing generator took 0:00:00.023043
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-01-16 17:29:57 INFO: Fixed route router took 0:00:00.022226
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Application Router took 0:00:00.019608
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Basic tag allocator took 0:00:00.065662
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Tag allocator report took 0:00:00.019856
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Zoned routing info allocator took 0:00:00.036997
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Router info report took 0:00:00.020021
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Merged routing table generator took 0:00:00.018406
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Uncompressed routing table report took 0:00:00.018765
# 2024-01-16 17:29:57 INFO: Router report skipped as cfg Reports:write_router_reports is False
# 2024-01-16 17:29:57 INFO: Router summary report skipped as cfg Reports:write_router_summary_report is False
# 2024-01-16 17:29:57 INFO: Json routing tables skipped as cfg Reports:write_json_routing_tables is False
# 2024-01-16 17:29:57 INFO: Locate executable start type took 0:00:00.000592
# 2024-01-16 17:29:57 INFO: Buffer manager creator took 0:00:00.002318
# 2024-01-16 17:29:57 INFO: Write Neo Metadata took 0:00:00.003711
# 2024-01-16 17:29:57 INFO: Record vertex labels to database took 0:00:00.003290
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Routing setup took 0:00:00.025731
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Graph binary gatherer took 0:00:00.075456
# 2024-01-16 17:29:57 INFO: Pair on chip router compression skipped as Tables already small enough
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: SDRAM outgoing partition allocator took 0:00:00.021663
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Graph data specification writer took 0:00:00.135598
# 2024-01-16 17:29:57 INFO: Control Sync took 0:00:00.000939
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:29:57 INFO: Load fixed routes took 0:00:00.070447
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:02 INFO: Load system data specification took 0:00:04.860500
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:03 INFO: Load executable system Images took 0:00:00.305807
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:03 INFO: Tags Loader took 0:00:00.058239
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:07 INFO: Load Application data specification took 0:00:03.947253
# Preparing to Expand Neuron Data
# |0%                          50%                         100%|
#  ============================================================
# Expanding Neuron Data
# |0%                          50%                         100%|
#  ============================================================
#
# Getting initial values
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:07 INFO: Neuron expander took 0:00:00.843007
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:07 INFO: Synapse expander took 0:00:00.057974
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Finish connection holders took 0:00:00.017682
# Loading routing data onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Routing table loader took 0:00:00.019875
# 2024-01-16 17:30:08 INFO: Bitfield compressor report skipped as cfg Reports:write_bit_field_compressor_report is False
# 2024-01-16 17:30:08 INFO: Tags from machine report took 0:00:00.011501
# 2024-01-16 17:30:08 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# 2024-01-16 17:30:08 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Compressor report took 0:00:00.124185
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Fixed route report took 0:00:00.072242
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Load executable app images took 0:00:00.400744
# 2024-01-16 17:30:08 INFO: Running for 1 steps for a total of 1000.0ms
# 2024-01-16 17:30:08 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Sdram usage per chip report took 0:00:00.113661
# 2024-01-16 17:30:08 INFO: Drift report skipped as cfg Reports:write_drift_report_start is False
# 2024-01-16 17:30:08 INFO: Creating live event connection database in /home/bbpnrsoa/reports/reports/2024-01-16-17-29-35-093649/run_1/input_output_database.sqlite3
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:08 INFO: Create database interface took 0:00:00.055520
# 2024-01-16 17:30:08 INFO: ** Notifying external sources that the database is ready for reading **
# 2024-01-16 17:30:08 INFO: Create notification protocol took 0:00:00.005627
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  2024-01-16 17:30:08 INFO: 0.0.0.0:43906 Reading database
# 2024-01-16 17:30:08 INFO: database is at /home/bbpnrsoa/reports/reports/2024-01-16-17-29-35-093649/run_1/input_output_database.sqlite3
# 2024-01-16 17:30:08 INFO: Listening for traffic from pop on board 10.11.200.177 on 0.0.0.0:47559
# ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:09 INFO: Runtime Update took 0:00:00.211960
# 2024-01-16 17:30:09 INFO: *** Running simulation... ***
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:09 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:30:09 INFO: Notifying the toolchain that the database has been read
# 2024-01-16 17:30:09 INFO: Waiting for message to indicate that the simulation has started or resumed
# 2024-01-16 17:30:09 INFO: ** Confirmation from 127.0.0.1:43906 received, continuing **
# 2024-01-16 17:30:09 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2024-01-16 17:30:09 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:30:09 INFO: Application started; waiting 1.1s for it to stop
# 2024-01-16 17:30:09 INFO: Waiting for message to indicate that the simulation has stopped or paused
# Received spikes [2] from pop at time 12
# Received spikes [4] from pop at time 31
# Received spikes [3] from pop at time 49
# Received spikes [2] from pop at time 66
# Received spikes [4] from pop at time 72
# Received spikes [1] from pop at time 77
# Received spikes [2] from pop at time 131
# Received spikes [0] from pop at time 133
# Received spikes [3] from pop at time 147
# Received spikes [4] from pop at time 171
# Received spikes [3] from pop at time 209
# Received spikes [0] from pop at time 218
# Received spikes [0] from pop at time 237
# Received spikes [0] from pop at time 244
# Received spikes [3] from pop at time 259
# Received spikes [2] from pop at time 266
# Received spikes [1, 2, 3] from pop at time 275
# Received spikes [0] from pop at time 303
# Received spikes [4] from pop at time 311
# Received spikes [1] from pop at time 345
# Received spikes [3] from pop at time 351
# Received spikes [1] from pop at time 352
# Received spikes [4] from pop at time 355
# Received spikes [3] from pop at time 356
# Received spikes [1] from pop at time 402
# Received spikes [3] from pop at time 428
# Received spikes [0] from pop at time 441
# Received spikes [4] from pop at time 448
# Received spikes [1] from pop at time 451
# Received spikes [0] from pop at time 460
# Received spikes [0] from pop at time 471
# Received spikes [2] from pop at time 490
# Received spikes [2] from pop at time 509
# Received spikes [3] from pop at time 537
# Received spikes [3] from pop at time 583
# Received spikes [4] from pop at time 616
# Received spikes [4] from pop at time 617
# Received spikes [4] from pop at time 635
# Received spikes [0] from pop at time 657
# Received spikes [0] from pop at time 660
# Received spikes [4] from pop at time 662
# Received spikes [1] from pop at time 673
# Received spikes [4] from pop at time 688
# Received spikes [1] from pop at time 718
# Received spikes [0] from pop at time 773
# Received spikes [1] from pop at time 781
# Received spikes [4] from pop at time 790
# Received spikes [0] from pop at time 791
# Received spikes [3] from pop at time 802
# Received spikes [1] from pop at time 805
# Received spikes [1] from pop at time 811
# Received spikes [0] from pop at time 842
# Received spikes [2] from pop at time 846
# Received spikes [4] from pop at time 953
# 2024-01-16 17:30:11 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2024-01-16 17:30:11 INFO: Application runner took 0:00:01.960115
# 2024-01-16 17:30:11 INFO: Extract IO buff skipped as cfg Reports:extract_iobuf is False
# 2024-01-16 17:30:11 INFO: Starting buffer extraction using Java
# 2024-01-16 17:30:11 INFO: Buffer extractor took 0:00:00.004939
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:11 INFO: Clear IO buffer took 0:00:00.016992
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:11 INFO: Graph provenance gatherer took 0:00:00.003939
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:11 INFO: Placements provenance gatherer took 0:00:00.293761
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:11 INFO: Router provenance gatherer took 0:00:00.259318
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:11 INFO: Profile data gatherer took 0:00:00.038271
# 2024-01-16 17:30:11 INFO: Energy report skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:30:11 INFO: Redundant packet count report took 0:00:00.005519
# 2024-01-16 17:30:11 INFO: Drift report skipped as cfg Reports:write_drift_report_end is False
# 2024-01-16 17:30:11 INFO: Control Sync took 0:00:00.000714

# %% [markdown]
# ### Live Rate Input - add_poisson_live_rate_control
#
# <img src="PoissonControl.png">
#
# The spike rate of a ```SpikeSourcePoisson``` can be controlled during the simulation, by calling a function ```add_poisson_live_rate_control```, passing in the Poisson source to be controlled, as well as other parameters of the communication if required.  This will set up a mechanism by which the Poisson rates can be changed by sending SDP packets containing multicast keys and rates.  A ```SpynnakerPoissonControlConnection``` can by used by the external agent to send these packets without requiring knowledge of this mechanism.  Note that multiple sources can be controlled with the same connection.
#
# The software on SpiNNaker makes some assumptions using the rates of Poisson spikes sources, therefore it is important to tell the source what the maximum rate to expect will be.  This is done by providing a value for ```max_rate``` using the  ```additional_parameters``` of the Population of the source.  This may or may not be critical for the functioning of the network depending on how high the rate goes, and whether or not the source is being recorded; in particular space for recording will be reserved based on this value, so if the rate increases during simulation, recorded values may be lost.
#
# The following is an example of live Poisson rate control:

# %%
# Import the simulator
import spynnaker.pyNN as sim

# Other imports used in this example
from time import sleep
import pyNN.utility.plotting as plot


# Set up a function that will start setting rates when the simulation starts.
# This is automatically run in a separate thread from the rest of the simulation.
# This must accept two arguments: 
#    The label of the Population that the callback is registered against, 
#    and the connection the callback is registered against.
def set_rates(label, connection):
    try:
        # Set the rate of neuron 0 to 10Hz at about 100ms
        sleep(0.1)
        print("Setting rate of 0")
        connection.set_rate(label, 0, 10)

        # Set the rate of neurons 1-4 to 50Hz at about 500ms
        sleep(0.4)
        print("Setting rate of 1-4")
        connection.set_rates(label, [(i, 50) for i in range(1, 5)])
    except Exception:
        import traceback
        traceback.print_exc()


# Keep track of the label of the Population
pop_label = "pop"

# Create the connection, noting that the label will be the controlled source.
# Note the use of local_port=None allows the automatic assignment of a port.
connection = sim.external_devices.SpynnakerPoissonControlConnection(
    local_port=None, poisson_labels=[pop_label])

# Add a callback to be called at the start of the simulation
connection.add_start_resume_callback(pop_label, set_rates)

# Set up the simulation itself
sim.setup(1.0)

# Set up a population which will spike
pop = sim.Population(
    5, sim.SpikeSourcePoisson(rate=0),
    # Provide an additional argument to indicate that the rate will change
    additional_parameters={'max_rate': 50},
    # Critical: Make sure the label is used!
    label=pop_label)

# Record the population
pop.record("spikes")

# Specify that this Poisson source is to be controlled,
# simultaneously registering the connection as a listener
sim.external_devices.add_poisson_live_rate_control(
    pop, database_notify_port_num=connection.local_port)

# Run the simulation and get the spikes
sim.run(1000)
spikes = pop.get_data("spikes").segments[0].spiketrains

# End the simulation and plot the spikes
sim.end()
plot.Figure(
    plot.Panel(spikes, yticks=True, markersize=5, xlim=(0, 1000)),
    title="Poisson Spikes"
)
# Out:
# 2024-01-16 17:30:11 INFO: 0.0.0.0:35610 Waiting for message to indicate that the database is ready
# 2024-01-16 17:30:11 INFO: Read configs files: /home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg, /home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg, /home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2024-01-16 17:30:11 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/model_binaries : /home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/common_model_binaries
# 2024-01-16 17:30:12 WARNING: /home/bbpnrsoa/reports/reports has 76 old reports that have not been closed
# 2024-01-16 17:30:12 INFO: Setting hardware timestep as 1000 microseconds based on simulation time step of 1000 and timescale factor of 1.0
# 2024-01-16 17:30:12 INFO: Starting execution process
# 2024-01-16 17:30:12 INFO: Simulating for 1000 1.0 ms timesteps using a hardware timestep of 1000 us
# ['/home/bbpnrsoa/sPyNNakerGit/SpiNNUtils/spinn_utilities/spinn_utilities.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMachine/spinn_machine/spinn_machine.cfg', '/home/bbpnrsoa/sPyNNakerGit/PACMAN/pacman/pacman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNMan/spinnman/spinnman.cfg', '/home/bbpnrsoa/sPyNNakerGit/SpiNNFrontEndCommon/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNakerGit/sPyNNaker/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']
# 2024-01-16 17:30:12 INFO: SpYNNakerNeuronGraphNetworkSpecificationReport skipped as cfg Reports:write_network_graph is False
# 2024-01-16 17:30:12 INFO: Network Specification report took 0:00:00.000697
# 2024-01-16 17:30:12 INFO: Splitter reset took 0:00:00.000030
# Adding Splitter selectors where appropriate
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:12 INFO: Spynnaker splitter selector took 0:00:00.020629
# Adding delay extensions as required
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:12 INFO: DelaySupportAdder took 0:00:00.008327
# Partitioning Graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:12 INFO: Splitter partitioner took 0:00:00.004865
# 2024-01-16 17:30:12 INFO: 0.02 Boards Required for 1 chips
# 2024-01-16 17:30:12 INFO: Requesting job with 1 boards
# Created spalloc job 379110
# 2024-01-16 17:30:12 INFO: Created spalloc job 379110
# Job has been queued by the spalloc server.
# 2024-01-16 17:30:12 INFO: Job has been queued by the spalloc server.
# Waiting for board power commands to complete.
# 2024-01-16 17:30:15 INFO: Waiting for board power commands to complete.
# 2024-01-16 17:30:24 INFO: SpallocAllocator took 0:00:12.350345
# 2024-01-16 17:30:24 INFO: Creating transceiver for 10.11.210.121
# 2024-01-16 17:30:24 INFO: Working out if machine is booted
# 2024-01-16 17:30:28 INFO: Attempting to boot machine
# 2024-01-16 17:30:36 INFO: Found board with version [Version: SC&MP 4.0.0 at SpiNNaker:0:0:0 (built Fri Nov 17 10:35:48 2023)]
# 2024-01-16 17:30:36 INFO: Machine communication successful
# 2024-01-16 17:30:36 INFO: 10.11.210.121
# Reading details from 48 chips
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:36 INFO: Detected Machine on 10.11.210.121 with 48 Chips, 856 cores and 120.0 links. Chips have sdram of 123469792 bytes, router table of size 1023, between 17 and 18 cores and between 3 and 6 links.
# 2024-01-16 17:30:36 INFO: Machine generator took 0:00:12.251324
# 2024-01-16 17:30:36 INFO: Json machine skipped as cfg Reports:write_json_machine is False
# Writing the board chip report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:36 INFO: Board chip report took 0:00:00.017772
# Adding commands
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:36 INFO: Command Sender Adder took 0:00:00.016666
# 2024-01-16 17:30:36 INFO: Split Live Gather Vertices took 0:00:00.000040
# 2024-01-16 17:30:36 INFO: Insert chip power monitors skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:30:36 INFO: Insert extra monitor vertices took 0:00:00.000058
# Inserting extra monitors into graphs
# |0%                          50%                         100%|
#  ============================================================
# Generating partitioner report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:36 INFO: Partitioner report took 0:00:00.004332
# Placing Vertices
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:36 INFO: Application Placer took 0:00:00.011275
# Generating placement report
# |0%                          50%                         100%|
#  ============================================================
# Generating placement by core report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Placements with application graph report took 0:00:00.043423
# 2024-01-16 17:30:37 INFO: Json placements skipped as cfg Reports:write_json_placements is False
# Generating routing tables for data in system processes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: System multicast routing generator took 0:00:00.009973
# Generating fixed router routes
# |0%                          50%                         100%|
#  ============================================================
#
# 2024-01-16 17:30:37 INFO: Fixed route router took 0:00:00.011348
# Routing
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Application Router took 0:00:00.003846
# Allocating tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Basic tag allocator took 0:00:00.040710
# Reporting Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Tag allocator report took 0:00:00.014468
# Calculating zones
# |0%                          50%                         100%|
#  ============================================================
# Allocating routing keys
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Zoned routing info allocator took 0:00:00.006054
# Generating Routing info report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Router info report took 0:00:00.003368
# Generating routing tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Merged routing table generator took 0:00:00.013510
# Generating Router table report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Uncompressed routing table report took 0:00:00.003606
# 2024-01-16 17:30:37 INFO: Router report skipped as cfg Reports:write_router_reports is False
# 2024-01-16 17:30:37 INFO: Router summary report skipped as cfg Reports:write_router_summary_report is False
# 2024-01-16 17:30:37 INFO: Json routing tables skipped as cfg Reports:write_json_routing_tables is False
# 2024-01-16 17:30:37 INFO: Locate executable start type took 0:00:00.000512
# 2024-01-16 17:30:37 INFO: Buffer manager creator took 0:00:00.002329
# 2024-01-16 17:30:37 INFO: Write Neo Metadata took 0:00:00.005520
# 2024-01-16 17:30:37 INFO: Record vertex labels to database took 0:00:00.003337
# Preparing Routing Tables
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Routing setup took 0:00:00.038818
# Finding binaries
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Graph binary gatherer took 0:00:00.033787
# 2024-01-16 17:30:37 INFO: Pair on chip router compression skipped as Tables already small enough
# Allocating SDRAM for SDRAM outgoing egde partitions
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: SDRAM outgoing partition allocator took 0:00:00.003651
# Generating data specifications
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Graph data specification writer took 0:00:00.219391
# 2024-01-16 17:30:37 INFO: Control Sync took 0:00:00.002393
# loading fixed routes
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:37 INFO: Load fixed routes took 0:00:00.125701
# Executing data specifications and loading data for system vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:42 INFO: Load system data specification took 0:00:04.478078
# Loading system executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:42 INFO: Load executable system Images took 0:00:00.293764
# Clearing tags
# |0%                          50%                         100%|
#  ============================================================
# Loading Tags
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:42 INFO: Tags Loader took 0:00:00.037921
# Executing data specifications and loading data for application vertices using Java
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:46 INFO: Load Application data specification took 0:00:03.848618
# Preparing to Expand Neuron Data
# |0%                          50%                         100%|
#  ============================================================
# Expanding Neuron Data
# |0%                          50%                         100%|
#  ============================================================
#
# Getting initial values
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:46 INFO: Neuron expander took 0:00:00.601862
# Preparing to Expand Synapses
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Synapse expander took 0:00:00.045991
# Finalising Retrieved Connections
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Finish connection holders took 0:00:00.011404
# Loading routing data onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Routing table loader took 0:00:00.027606
# 2024-01-16 17:30:47 INFO: Bitfield compressor report skipped as cfg Reports:write_bit_field_compressor_report is False
# 2024-01-16 17:30:47 INFO: Tags from machine report took 0:00:00.006942
# 2024-01-16 17:30:47 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# 2024-01-16 17:30:47 INFO: Memory report skipped as cfg Reports:write_memory_map_report is False
# Generating compressed router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating comparison of router table report
# |0%                          50%                         100%|
#  ============================================================
# Generating Routing summary report
# |0%                          50%                         100%|
#  ============================================================
# Reading Routing Tables from Machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Compressor report took 0:00:00.158261
# Writing fixed route report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Fixed route report took 0:00:00.083313
# Loading executables onto the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Load executable app images took 0:00:00.438127
# 2024-01-16 17:30:47 INFO: Running for 1 steps for a total of 1000.0ms
# 2024-01-16 17:30:47 INFO: Run 1 of 1
# Generating SDRAM usage report
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:47 INFO: Sdram usage per chip report took 0:00:00.135801
# 2024-01-16 17:30:47 INFO: Drift report skipped as cfg Reports:write_drift_report_start is False
# 2024-01-16 17:30:47 INFO: Creating live event connection database in /home/bbpnrsoa/reports/reports/2024-01-16-17-30-11-892195/run_1/input_output_database.sqlite3
# Creating graph description database
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:48 INFO: Create database interface took 0:00:00.035995
# 2024-01-16 17:30:48 INFO: Create notification protocol took 0:00:00.001559
# Waiting for cores to be either in PAUSED or READY state
# |0%                          50%                         100%|
#  2024-01-16 17:30:48 INFO: ** Notifying external sources that the database is ready for reading **
# 2024-01-16 17:30:48 INFO: 0.0.0.0:35610 Reading database
# ============================================================
# Updating run time
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:48 INFO: Runtime Update took 0:00:00.050562
# 2024-01-16 17:30:48 INFO: database is at /home/bbpnrsoa/reports/reports/2024-01-16-17-30-11-892195/run_1/input_output_database.sqlite3
# 2024-01-16 17:30:48 INFO: *** Running simulation... ***
# 2024-01-16 17:30:48 INFO: Notifying the toolchain that the database has been read
# 2024-01-16 17:30:48 INFO: Waiting for message to indicate that the simulation has started or resumed
# 2024-01-16 17:30:48 INFO: ** Confirmation from 127.0.0.1:35610 received, continuing **
# Loading buffers
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:30:48 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2024-01-16 17:30:48 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2024-01-16 17:30:48 INFO: Application started; waiting 1.1s for it to stop
# 2024-01-16 17:30:48 INFO: Waiting for message to indicate that the simulation has stopped or paused
# Setting rate of 0
# Setting rate of 1-4
# 2024-01-16 17:30:49 INFO: ** Sending pause / stop message to external sources to state the simulation has been paused or stopped. **
# 2024-01-16 17:30:49 INFO: Application runner took 0:00:01.230273
# 2024-01-16 17:30:49 INFO: Extract IO buff skipped as cfg Reports:extract_iobuf is False
# 2024-01-16 17:30:49 INFO: Starting buffer extraction using Java
# 2024-01-16 17:30:53 INFO: Buffer extractor took 0:00:03.680122
# clearing IOBUF from the machine
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:53 INFO: Clear IO buffer took 0:00:00.024748
# Getting provenance data from application graph
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:53 INFO: Graph provenance gatherer took 0:00:00.007696
# Getting provenance data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:53 INFO: Placements provenance gatherer took 0:00:00.308782
# Getting Router Provenance
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:53 INFO: Router provenance gatherer took 0:00:00.277043
# Getting profile data
# |0%                          50%                         100%|
#  ============================================================
# 2024-01-16 17:30:53 INFO: Profile data gatherer took 0:00:00.042524
# 2024-01-16 17:30:53 INFO: Energy report skipped as cfg Reports:write_energy_report is False
# 2024-01-16 17:30:53 INFO: Redundant packet count report took 0:00:00.006192
# 2024-01-16 17:30:53 INFO: Drift report skipped as cfg Reports:write_drift_report_end is False
# 2024-01-16 17:30:53 INFO: Control Sync took 0:00:00.005061
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Live Voltage Output - Robot Control
#
# <img src="VoltageOutput.png">
#
# The software provides a specific neuron model, ```ExternalDeviceLifControl```, which is designed to be used to output samples of the membrane voltage of the neuron during simulation.  This could be used, for example, to control the speed of a motor in a robot.  The values are again contained in SDP packets containing pairs of multicast keys and payloads, which are described as commands.  This additionally differs from the spike output in that the multicast keys can be specified by the user rather than being assigned by the software; for this reason some care must be taken not to use the same key in multiple different places (though the software will check this and report an error if encountered).  It is also possible to configure other aspects of the communication, such as how often the value is transmitted, the minimum and maximum values, and even the binary format of the value.  These parameters are encapsulated in the ```AbstractMulticastControllableDevice```, a set of which are provided to the ```ExternalDeviceLifControl```.
#
# The software also provides an ```EthernetControlConnection``` to allow the decoding of these packets by an external agent.  This is different from the other connections in that it also takes an ```AbstractEthernetTranslator```, which is asked to translate each received message.  This might, for example, convert the message into a command for a robot.
#
# To avoid the complexities of building the connection, population, and all the other parts required, an ```EthernetControlPopulation``` is provided.  This will return a ```Population``` object which can be used as the target of a ```Projection```.
#
# An example of this interaction is shown below:

# %%
# Import the simulator
import spynnaker.pyNN as sim

# Import the extra classes
from spinn_front_end_common.interface.ds import DataType
from spynnaker.pyNN.external_devices_models import (
    AbstractEthernetTranslator, AbstractMulticastControllableDevice)
from spynnaker.pyNN.external_devices_models\
    .abstract_multicast_controllable_device import SendType


class TestTranslator(AbstractEthernetTranslator):
    
    def translate_control_packet(self, packet):
        print("Received key={}, voltage={}".format(
            packet.key, packet.payload / DataType.S1615.max))
    

class TestDevice(AbstractMulticastControllableDevice):
    
    @property
    def device_control_partition_id(self):
        # This should be unique to the device, but is otherwise unimportant
        return "Test"
    
    @property
    def device_control_key(self):
        # This should be unique to the device
        return 0
    
    @property
    def device_control_uses_payload(self):
        # This returns True to receive the voltage, 
        # or False if only the key is desired
        return True
    
    @property
    def device_control_min_value(self):
        # Return the minimum value accepted by the device.  If the membrane
        # voltage is below this value, this value will be used.
        return 0
    
    @property
    def device_control_max_value(self):
        # Return the maximum value accepted by the device.  If the membrane
        # voltage is above this value, this value will be used.
        return 100
    
    @property
    def device_control_timesteps_between_sending(self):
        # The number of timesteps between sending values.  Controls the
        # update rate of the value.
        return 10
    
    @property
    def device_control_send_type(self):
        # The type of the value - one of the SendType values
        return SendType.SEND_TYPE_ACCUM
    
    @property
    def device_control_scaling_factor(self):
        # The amount to multiply the voltage by before transmission
        return 1.0
    

# Setup the simulation
sim.setup(1.0)

# Create some stimulation
stim = sim.Population(1, sim.SpikeSourcePoisson(rate=50), label="stim")

# Create the model that will generate the voltage
pop = sim.external_devices.EthernetControlPopulation(
    n_neurons=1,
    model=sim.external_devices.ExternalDeviceLifControl(
        devices=[TestDevice()],
        create_edges=False,
        translator=TestTranslator()),
    label="test")

# Connect the stimulation to the population
sim.Projection(stim, pop, sim.OneToOneConnector(), sim.StaticSynapse(weight=1))

# Run the simulation then stop
sim.run(1000)
sim.end()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-bc1ed7b58b77> in <module>
#       7 from spynnaker.pyNN.external_devices_models\
#       8     .abstract_multicast_controllable_device import SendType
# ----> 9 from data_specification.enums import DataType
#      10
#      11
#
# ModuleNotFoundError: No module named 'data_specification'

# %% [markdown]
# ## Excercises
# The following exercises are designed to enhance your understanding of the use of Live I/O with SpiNNaker.  You have the option of following the step-by-step instructions in the linked notebooks, or you can try to follow the instructions below each task (this will be harder).
#
#  - [Task 1: Send data (Easy)](task1.ipynb)
#     - Create a network with a timestep of 1.0ms consisting of 100 LIF neurons which are randomly connected to each other with a probability of 0.08, using a weight of 0.5nA and a delay of 2ms and which are all stimulated from a single SpikeInjector neuron with a weight of 5nA and a delay of 1.0ms. Send spikes into the network using the injector at approximately 100ms intervals.  Record the LIF neurons and run for 1000ms, plotting the results after the simulation has completed.
#
#  - [Task 2: Receive data (Easy)](task2.ipynb)
#     - Create a network with a timestep of 1.0ms consisting of 100 Poisson neurons connected with a probability of 0.1 to 100 LIF neurons, with a weight of 0.5nA and a delay of 1ms.  Don't record the Population; instead receive the spikes live from the Population and print out when each spike or spikes arrive.
#
#  - [Task 3: Rate Changes (Easy)](task3.ipynb)
#      - Using the network described in Task 2 above, record the LIF neurons rather than extracting the live spikes.  Instead, set the Poisson neurons to 0Hz initially but allow them to have a maximum rate of 100Hz.  Change the rate of the Poisson sources during the simulation progressively to 10Hz, 20Hz, 50Hz and 100Hz with 0.2 seconds in between each.  Plot the results after the simulation has completed.
#
#  - [Task 4: Receive Voltage (Moderate)](task4.ipynb)
#      - Create a network with a timestep of 1.0ms consisting of 100 Poisson neurons all connected to a single neuron external control Population using a weight of 0.1nA and a delay of 1ms.  Create a device that sends the voltage using integers in the range -50 to 50mV every 5ms using a key of 10.  Create a translator that receives the voltage and prints out the value.
